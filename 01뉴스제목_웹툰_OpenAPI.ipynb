# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
! pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# !pip install requests beautifulsoup4

import requests
from bs4 import BeautifulSoup

url = 'https://example.com'
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.title)
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# <title>Example Domain</title>

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://example.com'
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.title)
# Out:
# <title>Example Domain</title>

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python313\python.exe

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\user\anaconda3\python.exe

# %%
# reqeusts, bs4 import
import requests

# BeautifulSoup 클래스 import
import bs4

# Beautifulsoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
sid = 104
#url = f'https://news.naver.com/section/{sid}'

url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)
# Out:
# https://news.naver.com/section/105

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
}

# requests 의 get() 함수 호출하기 
res=requests.get(url,headers=req_header)
print(res.status_code, res.ok)
print(type(res))
print(res)

# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
if res.ok:
    html = res.text
    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")   
    #print(soup)
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))

    '''
       <div class='sa_text'> 
          <a href="https://n.news.naver.com/mnews/article/366/0001094461" class="sa_text_title">
    '''
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/article'].sa_text_title")
    print(len(a_tags))
    print(type(a_tags)) #[Tag,Tag,Tag]
    for idx,a_tag in enumerate(a_tags,1):
        if a_tag.text:
           title = a_tag.text.strip()
           #print(len(title))
           print(f'{idx} {title}')
     
        
    # <a> 태그 리스트 순회하기    
    for idx, a_tag in enumerate(a_tags,1):        
        if a_tag.text:
            title = a_tag.text.strip() # 제목
            link = a_tag['href'] # 링크
            #print(len(title))
            print(f'{idx} {title} {link}')
else:
    
    # 응답(response)이 Error 이면 status code 출력    
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200 True
# <class 'requests.models.Response'>
# <Response [200]>
# 44
# <class 'bs4.element.ResultSet'>
# 1 배경훈 과기부 장관 “‘AI 고속도로’ 데이터센터,  AI 3대 강국 출발점”
# 2 개인정보위, 네이버·카카오 등에 '개인정보 동의 축소' 권고
# 3 카카오, 경량 멀티모달 언어모델 공개…이미지 이해도 GPT-4o 비견
# 4 삼성SDS, 2분기 매출·영업익 전년비 4.2%씩 증가
# 5 고해상도 광학관측위성 '아리랑 7호' 11월 발사
# 6 “갤럭시Z폴드 덕분이야”...’폴더블폰 부품주’ 도이인시스 상장 첫날 강세
# 7 SKT, 독자 개발 'A.X 3.1' 공개…"추론 모델로 확장"[AI픽]
# 8 '안전조치 의무 위반'…개인정보위, 해성디에스 개인정보 유출에 과징금 3.4억원
# 9 네이버 클로바 스피치, 금융권 보안 관문 뚫었다…AI 음성인식 확대 '신호탄'
# 10 중국 폴더블폰 실측해보니…"광고보다 최대 0.6㎜ 두꺼워"
# 11 2억4700만년 전 볏 달린 파충류 확인…"'깃털 공룡' 존재 뒷받침"
# 12 [단독]'혈액치매진단' 피플바이오, 3분기 中하이난 진출 유력
# 13 LG디스플레이, 2분기 영업손실 1160억원… OLED 수요 감소·환율 여파에 적자 폭 확대
# 14 과기장관 "GPU 5만장 앞당겨 확보…국내 AIDC 활성화 총력"(종합)
# 15 HD현대건설기계, 2분기 영업익 400억원…전년비 31.6%↓
# 16 “나 지렁이 아니다”…세계서 가장 작은 10㎝ 뱀 20년 만에 발견 [핵잼 사이언스]
# 17 도우인시스, 애플 폴더블폰 출시…초박형 강화유리 사실상 독과점 수혜 전망
# 18 "3000원  추가시 최대 5인"…SKT, 로밍 쿠폰 반값 할인
# 19 두나무, 업비트 데이터랩에 솔라나·수이 생태계 지수 추가
# 20 [현장] 에퀴닉스 "AI 인프라는 지속가능한 플랫폼…韓도 액체 냉각 전환"
# 21 [인터뷰] “美 수출하는 뇌 수술 로봇, 경쟁력 충분”
# 22 ‘독자 AI’ 도전장 던진 SKT, 340억개 매개변수 기반 ‘A.X 3.1’ 공개
# 23 “‘싼 것’ 찾다간 낭패” 유산균에 붙은 ‘이 숫자’, 유럽에선 ‘의무사항’
# 24 지상의 ‘피자 크기 물체’ 탐지…초고해상도 위성 아리랑 7호, 11월 우주로
# 25 SK하이닉스 미래 성장성, HBM4 가격협상·수익 방어에 달렸다
# 26 개인정보 수집 이미 동의했는데 페이·쇼핑에서 또? 개보위, 개선 권고
# 27 [ETRI, 6G 기술개발 선도한다] 2028년 핵심기술 구현 목표...표준화 병행해 성과 키운다
# 28 서울 11일만에 폭염 경보…27일까지 한반도 '펄펄'
# 29 ‘삼국지 전략판’ 쿠카게임즈, 주민번호 무단 수집…과징금 9천만 원
# 30 개인정보위 "카톡·네이버·쿠팡·배민·당근 슈퍼앱 불필요한 '동의' 줄여라" 권고
# 31 랜섬웨어 감염에 7만4천 주주·임직원 정보 유출, 해성디에스 등 과징금
# 32 "네이버보다 낫다"…카카오가 꺼낸 AI 모델에 '깜짝'
# 33 美 국무장관 목소리까지 사칭… AI '사기 위기'
# 34 SKT, T 로밍쿠폰 50% 타임 세일…1인 2매 한정
# 35 SK하이닉스 "올해 HBM 투자 확대 전망"…내년 '완판' 계획 순항(종합2보)
# 36 머스크 "xAI, 5년내 H100급 칩 5000만개 가동”
# 37 SK텔레콤, 자체 기술 ‘AI 모델’ ‘에이닷 엑스 3.1’ 오픈소스 공개
# 38 갤Z폴드·플립7을 반값에?…'단말 반납 혜택 프로그램' 주의보
# 39 법원, 'P2E 입법로비설' 위정현 학회장에 3천만원 배상 판결
# 40 SK하이닉스, 2분기 영업이익 절반 ‘HBM’서 나왔다… 실적 잔치 속 ‘과의존’ 우려도
# 41 사진 보여주니 “청계천 배경입니다” 답변 척척···카카오, 경량 AI 모델 2종 오픈소스로 공개
# 42 가장 얇다던 ‘아너 매직 V5’ 재보니.. "갤럭시 Z 폴드7이 더 얇네"
# 43 평택-시흥 민자고속도로, 왕복 4차로→왕복 6~8차로 확장
# 44 'API 인프라 강자' 쿠콘, 스테이블코인 시장 성장에 남몰래 웃는 이유는?
# 1 배경훈 과기부 장관 “‘AI 고속도로’ 데이터센터,  AI 3대 강국 출발점” https://n.news.naver.com/mnews/article/016/0002504355
# 2 개인정보위, 네이버·카카오 등에 '개인정보 동의 축소' 권고 https://n.news.naver.com/mnews/article/293/0000070198
# 3 카카오, 경량 멀티모달 언어모델 공개…이미지 이해도 GPT-4o 비견 https://n.news.naver.com/mnews/article/008/0005226224
# 4 삼성SDS, 2분기 매출·영업익 전년비 4.2%씩 증가 https://n.news.naver.com/mnews/article/029/0002970658
# 5 고해상도 광학관측위성 '아리랑 7호' 11월 발사 https://n.news.naver.com/mnews/article/422/0000763387
# 6 “갤럭시Z폴드 덕분이야”...’폴더블폰 부품주’ 도이인시스 상장 첫날 강세 https://n.news.naver.com/mnews/article/009/0005530158
# 7 SKT, 독자 개발 'A.X 3.1' 공개…"추론 모델로 확장"[AI픽] https://n.news.naver.com/mnews/article/001/0015526316
# 8 '안전조치 의무 위반'…개인정보위, 해성디에스 개인정보 유출에 과징금 3.4억원 https://n.news.naver.com/mnews/article/011/0004513062
# 9 네이버 클로바 스피치, 금융권 보안 관문 뚫었다…AI 음성인식 확대 '신호탄' https://n.news.naver.com/mnews/article/092/0002383370
# 10 중국 폴더블폰 실측해보니…"광고보다 최대 0.6㎜ 두꺼워" https://n.news.naver.com/mnews/article/001/0015527408
# 11 2억4700만년 전 볏 달린 파충류 확인…"'깃털 공룡' 존재 뒷받침" https://n.news.naver.com/mnews/article/584/0000033538
# 12 [단독]'혈액치매진단' 피플바이오, 3분기 中하이난 진출 유력 https://n.news.naver.com/mnews/article/018/0006073205
# 13 LG디스플레이, 2분기 영업손실 1160억원… OLED 수요 감소·환율 여파에 적자 폭 확대 https://n.news.naver.com/mnews/article/366/0001095252
# 14 과기장관 "GPU 5만장 앞당겨 확보…국내 AIDC 활성화 총력"(종합) https://n.news.naver.com/mnews/article/001/0015527339
# 15 HD현대건설기계, 2분기 영업익 400억원…전년비 31.6%↓ https://n.news.naver.com/mnews/article/092/0002383361
# 16 “나 지렁이 아니다”…세계서 가장 작은 10㎝ 뱀 20년 만에 발견 [핵잼 사이언스] https://n.news.naver.com/mnews/article/081/0003560616
# 17 도우인시스, 애플 폴더블폰 출시…초박형 강화유리 사실상 독과점 수혜 전망 https://n.news.naver.com/mnews/article/030/0003334856
# 18 "3000원  추가시 최대 5인"…SKT, 로밍 쿠폰 반값 할인 https://n.news.naver.com/mnews/article/138/0002201298
# 19 두나무, 업비트 데이터랩에 솔라나·수이 생태계 지수 추가 https://n.news.naver.com/mnews/article/014/0005381925
# 20 [현장] 에퀴닉스 "AI 인프라는 지속가능한 플랫폼…韓도 액체 냉각 전환" https://n.news.naver.com/mnews/article/092/0002383360
# 21 [인터뷰] “美 수출하는 뇌 수술 로봇, 경쟁력 충분” https://n.news.naver.com/mnews/article/366/0001095239
# 22 ‘독자 AI’ 도전장 던진 SKT, 340억개 매개변수 기반 ‘A.X 3.1’ 공개 https://n.news.naver.com/mnews/article/029/0002970723
# 23 “‘싼 것’ 찾다간 낭패” 유산균에 붙은 ‘이 숫자’, 유럽에선 ‘의무사항’ https://n.news.naver.com/mnews/article/016/0002504528
# 24 지상의 ‘피자 크기 물체’ 탐지…초고해상도 위성 아리랑 7호, 11월 우주로 https://n.news.naver.com/mnews/article/032/0003385054
# 25 SK하이닉스 미래 성장성, HBM4 가격협상·수익 방어에 달렸다 https://n.news.naver.com/mnews/article/092/0002383356
# 26 개인정보 수집 이미 동의했는데 페이·쇼핑에서 또? 개보위, 개선 권고 https://n.news.naver.com/mnews/article/018/0006073157
# 27 [ETRI, 6G 기술개발 선도한다] 2028년 핵심기술 구현 목표...표준화 병행해 성과 키운다 https://n.news.naver.com/mnews/article/030/0003334828
# 28 서울 11일만에 폭염 경보…27일까지 한반도 '펄펄' https://n.news.naver.com/mnews/article/584/0000033533
# 29 ‘삼국지 전략판’ 쿠카게임즈, 주민번호 무단 수집…과징금 9천만 원 https://n.news.naver.com/mnews/article/056/0011995454
# 30 개인정보위 "카톡·네이버·쿠팡·배민·당근 슈퍼앱 불필요한 '동의' 줄여라" 권고 https://n.news.naver.com/mnews/article/003/0013382336
# 31 랜섬웨어 감염에 7만4천 주주·임직원 정보 유출, 해성디에스 등 과징금 https://n.news.naver.com/mnews/article/008/0005226324
# 32 "네이버보다 낫다"…카카오가 꺼낸 AI 모델에 '깜짝' https://n.news.naver.com/mnews/article/015/0005162151
# 33 美 국무장관 목소리까지 사칭… AI '사기 위기' https://n.news.naver.com/mnews/article/665/0000005489
# 34 SKT, T 로밍쿠폰 50% 타임 세일…1인 2매 한정 https://n.news.naver.com/mnews/article/018/0006073144
# 35 SK하이닉스 "올해 HBM 투자 확대 전망"…내년 '완판' 계획 순항(종합2보) https://n.news.naver.com/mnews/article/001/0015527084
# 36 머스크 "xAI, 5년내 H100급 칩 5000만개 가동” https://n.news.naver.com/mnews/article/421/0008389970
# 37 SK텔레콤, 자체 기술 ‘AI 모델’ ‘에이닷 엑스 3.1’ 오픈소스 공개 https://n.news.naver.com/mnews/article/016/0002504505
# 38 갤Z폴드·플립7을 반값에?…'단말 반납 혜택 프로그램' 주의보 https://n.news.naver.com/mnews/article/138/0002201287
# 39 법원, 'P2E 입법로비설' 위정현 학회장에 3천만원 배상 판결 https://n.news.naver.com/mnews/article/092/0002383350
# 40 SK하이닉스, 2분기 영업이익 절반 ‘HBM’서 나왔다… 실적 잔치 속 ‘과의존’ 우려도 https://n.news.naver.com/mnews/article/366/0001095214
# 41 사진 보여주니 “청계천 배경입니다” 답변 척척···카카오, 경량 AI 모델 2종 오픈소스로 공개 https://n.news.naver.com/mnews/article/009/0005530381
# 42 가장 얇다던 ‘아너 매직 V5’ 재보니.. "갤럭시 Z 폴드7이 더 얇네" https://n.news.naver.com/mnews/article/014/0005381882
# 43 평택-시흥 민자고속도로, 왕복 4차로→왕복 6~8차로 확장 https://n.news.naver.com/mnews/article/092/0002383348
# 44 'API 인프라 강자' 쿠콘, 스테이블코인 시장 성장에 남몰래 웃는 이유는? https://n.news.naver.com/mnews/article/092/0002383347

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {100:'정치',101:'경제',102:'사회','생활/문화':103, 104:'세계',105:'IT/과학'}

def print_news(section):  #print_new(103,'생활/문화') 
    sid = section_dict[section]
    url = f'https://news.naver.com/section/{sid}'
    print(f'{url} {section} 뉴스')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
    }
    # requests 의 get() 함수 호출하기 
    res=requests.get(url,headers=req_header)
    print(res.status_code, res.ok)
    if res.ok:
        html = res.text
        # BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")   
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/article'].sa_text_title")
        print(len(a_tags))

         # <a> 태그 리스트 순회하기    
        for idx, a_tag in enumerate(a_tags,1):        
            if a_tag.text:
                title = a_tag.text.strip() # 제목
                link = a_tag['href'] # 링크
                #print(len(title))
                print(f'{idx} {title} {link}')
        
    else:
        # 응답(response)이 Error 이면 status code 출력    
        print(f'Error Code = {res.status_code}')

# %%
print_news('생활/문화')
# Out:
# https://news.naver.com/section/103 생활/문화 뉴스
# 200 True
# 44
# 1 폭염 키우고 태풍까지 밀어냈다…'이불' 두 고기압에 최고 38도 https://n.news.naver.com/mnews/article/421/0008389264
# 2 대한 마라톤 영웅이 눌러쓴 ‘KOREAN 손긔졍’… 광복 80주년 맞아 실물 첫 공개 https://n.news.naver.com/mnews/article/366/0001095255
# 3 한국GM, 서비스품질지수 자동차 AS 부문 7년 연속 1위 https://n.news.naver.com/mnews/article/001/0015526563
# 4 박보검이 부릅니다…"한국 관광의 주인공은 바로 당신!" https://n.news.naver.com/mnews/article/011/0004512985
# 5 현대차·기아, 상반기 유럽 판매량 53만9천대…작년보다 4.4％↓ https://n.news.naver.com/mnews/article/001/0015527440
# 6 서울 폭염경보…주말 한낮 38도 극한 폭염 예고[센터웨더] https://n.news.naver.com/mnews/article/422/0000763375
# 7 기아 "다문화 청소년, 글로벌 시대의 중요한 미래세대" https://n.news.naver.com/mnews/article/277/0005627205
# 8 유홍준 국립중앙박물관장 "한국미술 5천 년 세계 순회 전시회 추진" https://n.news.naver.com/mnews/article/052/0002223915
# 9 현대차, 2Q 잘 팔고도 ‘관세 직격탄’…영업익 15%↓(상보) https://n.news.naver.com/mnews/article/018/0006073268
# 10 7·8·9호 태풍 3개 동시 북상…한반도 폭염 영향은? https://n.news.naver.com/mnews/article/422/0000763413
# 11 이봉주 "4년 지옥 다녀온 기분"…희귀병 극복 후 깜짝 근황 https://n.news.naver.com/mnews/article/025/0003457401
# 12 "트럼프 車관세, 15% 아닌 12.5% 받아야 日과 동등한 수준" https://n.news.naver.com/mnews/article/421/0008390308
# 13 극우 유튜브에 빠진 아이 구출하기…피해자가 특권이 된 세상 https://n.news.naver.com/mnews/article/079/0004048691
# 14 백반집 폐업 증가 “반찬 가짓수 많아 너무 힘들어”…혈당ㆍ체중의 변화는? https://n.news.naver.com/mnews/article/296/0000091537
# 15 [날씨] 역대 가장 뜨거운 6·7월...토요일 폭염 절정 https://n.news.naver.com/mnews/article/052/0002223911
# 16 80세 할머니와 시작한 유튜브, 이렇게 될 줄 몰랐네요 https://n.news.naver.com/mnews/article/047/0002482181
# 17 현대차·기아, 6월 유럽 판매 8.7%↓…상반기 판매 4.4%↓ https://n.news.naver.com/mnews/article/018/0006073216
# 18 한화 3남의 야심작 '파이브가이즈'…떠도는 매각설에 입 열었다 https://n.news.naver.com/mnews/article/015/0005162174
# 19 BYD코리아 “씰, 구형 아냐…韓 전용 2026년식 모델” https://n.news.naver.com/mnews/article/029/0002970740
# 20 인적 끊겼던 인천공항 국내선 게이트, 국제선에 문호 열어 https://n.news.naver.com/mnews/article/009/0005530417
# 21 “‘좋은 식품’은 ‘건강기능식품’ 안 된다는 법, 국민 건강 가로막아” https://n.news.naver.com/mnews/article/028/0002757727
# 22 BYD "씰, 구형 재고떨이 아냐…한국 전용 2026년식" https://n.news.naver.com/mnews/article/018/0006073187
# 23 태풍 2개 동시에 북상 중...예상 경로도 '변수' [지금이뉴스] https://n.news.naver.com/mnews/article/052/0002223891
# 24 공중제비하다 시작된 통증…척수 손상으로 전신 마비된 16세 美 소녀 https://n.news.naver.com/mnews/article/296/0000091535
# 25 “3400만 원 들여 안면거상술” 60세 女, ‘후회한다’는 두 가지는? https://n.news.naver.com/mnews/article/346/0000094989
# 26 [오후날씨 꿀팁] 전국 대부분 폭염경보…토요일, 서울 38도 https://n.news.naver.com/mnews/article/056/0011995492
# 27 [날씨] 전국 곳곳 폭염 경보…주말 더위 '정점' https://n.news.naver.com/mnews/article/055/0001278104
# 28 '주말까지 최고 38도' 더위 심화 가능성도…폭염·열대야 일수 역대 2위 https://n.news.naver.com/mnews/article/003/0013382494
# 29 항암제로 치매 예방과 치료 할 수 있다? https://n.news.naver.com/mnews/article/296/0000091534
# 30 유홍준 국립중앙박물관장 "'한국미술 5천년' 세계 순회전 열 것" https://n.news.naver.com/mnews/article/001/0015527222
# 31 [날씨] 밤에 즐기는 물놀이‥주말, 올여름 최강 폭염 https://n.news.naver.com/mnews/article/214/0001438505
# 32 이불 두 겹 뒤집어 쓴 한반도…뜨거운 남동풍 주말 '38도 극한 폭염' https://n.news.naver.com/mnews/article/422/0000763371
# 33 두 번만 주문해도 1만원 더…"소비쿠폰 이렇게 쓰세요" https://n.news.naver.com/mnews/article/215/0001217455
# 34 28㎝ 작은 몸으로 아프리카서 2만7300㎞ 날아오는 대견한 ‘두견이’ https://n.news.naver.com/mnews/article/028/0002757722
# 35 여름 철새 '두견이' 아프리카 갔다 돌아왔다… 이동 경로 세계 첫 확인 https://n.news.naver.com/mnews/article/469/0000877838
# 36 LG엔솔, 중국 업체 배터리 특허침해 소송 3번째 승소…“앞으로도 엄정 대응” https://n.news.naver.com/mnews/article/032/0003385048
# 37 나, 건강한가? 궁금하다면 ‘다섯 가지’ 동작으로 확인 가능 https://n.news.naver.com/mnews/article/346/0000094988
# 38 날아오른 비둘기가 그려낸 한글…"유해동물이라며 미워만 마세요" https://n.news.naver.com/mnews/article/469/0000877827
# 39 계속되는 폭염, 당뇨·고혈압 있다면 ‘이 수치’ 주의해야 https://n.news.naver.com/mnews/article/346/0000094987
# 40 미술사 뒤집은 흑인 화가 보아포 "손가락 페인팅, 통제할 수 없어 즐겁다" https://n.news.naver.com/mnews/article/015/0005162136
# 41 관세 리스크에 비용 증가… 현대차, 믿을 건 '친환경차' https://n.news.naver.com/mnews/article/417/0001091184
# 42 尹, 내란 재판 3주 연속 불출석…특검 "구인영장 발부 요청" https://n.news.naver.com/mnews/article/374/0000453548
# 43 [날씨] 서울 '폭염경보' 발령…주말도 극한 폭염 이어져 https://n.news.naver.com/mnews/article/422/0000763326
# 44 '을릉 안간다'…비계 삼겹살 논란에 을릉군수 결국 사과 https://n.news.naver.com/mnews/article/374/0000453545

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=835751&no=24&week=tue',
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(url) #headers=req_header
    print(res.ok, res.status_code)
    if res.ok:      

        # binary 응답 데이터 가져오기
        img_data = res.content   

        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        
        # binday data를 file에 write하기
        with open(file_name, 'wb') as file:
            print(f'Writing to {file_name}({len(img_data):,} bytes)')
            file.write(img_data)
# Out:
# True 200
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg(296,868 bytes)
# True 200
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg(297,107 bytes)
# True 200
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg(296,877 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=835751&no=24&week=tue'
req_header = {
    'referer':webtoon_url,
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"
}
res = requests.get(webtoon_url)
print(res.status_code)
if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src$='.jpg']")))
    #https://image-comic.pstatic.net/webtoon
    print(len(soup.select("img[src^='https://image-comic.pstatic.net/webtoon']")))
    print(len(soup.select("img[src*='IMAG01']"))) # 일치함
    # img src file명을 저장할 list 선언
    img_url_list = list() #['http://xxx/aa.jpg']
    img_tags = soup.select("img[src*='IMAG01']") #img_tags의 타입은 Resultset [Tag,Tag,]
    for img_tag in img_tags: #img_tag 의 타입은 Tag <img>
        img_url = img_tag['src']
        img_url_list.append(img_url)
    #print(len(img_url_list), img_url_list[0:2])

    # img 디렉토리가 없으면 생성하기
    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for jpg_url in img_url_list:
        res = requests.get(jpg_url, headers=req_header)
        if res.ok:
            # binary data 추출하기
            img_data = res.content
            # img/xxx.jpg 디렉토리명과 jpg파일명을 join
            dir_name = os.path.join(imgdir_name,os.path.basename(jpg_url))
            with open(dir_name,'wb') as file:
                print(f'Writing to {dir_name}({len(img_data):,} bytes)')
                file.write(img_data)
        else:
           print(f'Error Code = {res.status_code}')
# Out:
# 200
# 88
# 88
# 62
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_1.jpg(110,240 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_2.jpg(157,933 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_3.jpg(143,514 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_4.jpg(165,592 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_5.jpg(129,768 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_6.jpg(171,935 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_7.jpg(105,653 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_8.jpg(81,579 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_9.jpg(134,745 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_10.jpg(117,224 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_11.jpg(117,395 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_12.jpg(113,038 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_13.jpg(37,205 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_14.jpg(160,861 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_15.jpg(114,631 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_16.jpg(157,889 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_17.jpg(107,030 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_18.jpg(129,748 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_19.jpg(107,847 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_20.jpg(159,660 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_21.jpg(101,543 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_22.jpg(136,852 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_23.jpg(136,915 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_24.jpg(130,937 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_25.jpg(95,064 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_26.jpg(139,225 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_27.jpg(123,893 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_28.jpg(148,422 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_29.jpg(94,414 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_30.jpg(131,480 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_31.jpg(83,206 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_32.jpg(159,920 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_33.jpg(104,163 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_34.jpg(121,671 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_35.jpg(112,359 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_36.jpg(132,663 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_37.jpg(135,863 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_38.jpg(97,199 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_39.jpg(118,361 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_40.jpg(85,495 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_41.jpg(101,979 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_42.jpg(153,576 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_43.jpg(85,324 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_44.jpg(54,056 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_45.jpg(92,771 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_46.jpg(133,727 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_47.jpg(106,838 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_48.jpg(123,974 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_49.jpg(169,554 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_50.jpg(151,026 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_51.jpg(53,263 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_52.jpg(73,862 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_53.jpg(99,761 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_54.jpg(94,812 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_55.jpg(68,898 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_56.jpg(53,576 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_57.jpg(132,611 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_58.jpg(155,826 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_59.jpg(77,885 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_60.jpg(156,088 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_61.jpg(134,727 bytes)
# Writing to img\20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_62.jpg(25,779 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
